# %%
print('Hello, Python!!!')
# Out:
# Hello, Python!!!

# %% [markdown]
# Cetak Nama dan NIM

# %%
print('Falikha Sulfiyah, 2420506042')
# Out:
# Falikha Sulfiyah, 2420506042

# %% [markdown]
# Weekly Exercise 1

# %%
print('Nama: Falikha Sulfiyah')
print('NPM : 2420506042')
print('Alamat : Kab. Cirebon, Jawa Barat')
print('Tinggi Badan : 155')
print('Berat Badan : 41')
# Out:
# Nama: Falikha Sulfiyah
# NPM : 2420506042
# Alamat : Kab. Cirebon, Jawa Barat
# Tinggi Badan : 155
# Berat Badan : 41

# %% [markdown]
# Weekly Exercise 2

# %%
print('\033[1m''UNIVERSITAS TIDAR''\033[0m')
print('Universitas Tidar merupakan Perguruan Tinggi Negeri Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia nomor 23 Tahun 2014 pada')
print("\n")
print('\033[1m''JURUSAN ELEKTRO, MEKATRONIKA, DAN INFORMASI''\033[0m')
print('Jurusan Teknik Elektro, Mekatronika, dan Informasi terdiri atas tiga program studi, antara lain: ')
print('1. S1 Teknik Elektro (\x1b[3mBachelor of Electrical Engineering\x1b[0m)')
print('2. S1 Tekonologi Informasi (\x1b[3mBachelor of Informtion Technology\x1b[0m)')
print('3, Teknik Mekatronika (\x1b[3mBachelor of Mechatronics Engineering\x1b[0m)')
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Negeri Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia nomor 23 Tahun 2014 pada
#
#
# JURUSAN ELEKTRO, MEKATRONIKA, DAN INFORMASI
# Jurusan Teknik Elektro, Mekatronika, dan Informasi terdiri atas tiga program studi, antara lain:
# 1. S1 Teknik Elektro (Bachelor of Electrical Engineering)
# 2. S1 Tekonologi Informasi (Bachelor of Informtion Technology)
# 3, Teknik Mekatronika (Bachelor of Mechatronics Engineering)
